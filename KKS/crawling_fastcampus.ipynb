# %% [markdown]
# # crawling

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
# webdriver 연결
browser = webdriver.Chrome()

# %%
# 네이버블로그 패스트캠퍼스 후기 검색 페이지 연결
url = 'https://section.blog.naver.com/Search/Post.naver?pageNo=1&rangeType=ALL&orderBy=sim&keyword=%ED%8C%A8%EC%8A%A4%ED%8A%B8%EC%BA%A0%ED%8D%BC%EC%8A%A4%20%ED%9B%84%EA%B8%B0'
browser.get(url)

# %%
# 페이지 연결 element 가져오기
pages_elements = browser.find_element(By.CLASS_NAME, 'pagination').find_elements(By.CLASS_NAME, 'item')

len(pages_elements)
# Out:
# 10

# %%
pagenum = 10
contents_list = []
for i in range(pagenum):
    # if idx > 0:
    #     break

    # page.click()
    browser.get(f'https://section.blog.naver.com/Search/Post.naver?pageNo={i+1}&rangeType=ALL&orderBy=sim&keyword=%ED%8C%A8%EC%8A%A4%ED%8A%B8%EC%BA%A0%ED%8D%BC%EC%8A%A4%20%ED%9B%84%EA%B8%B0')
    time.sleep(1)

    links_element = browser.find_elements(By.CLASS_NAME, 'desc_inner')
    links_review = []
    for link in links_element:
        links_review.append(link.get_attribute('href'))
        print(link.get_attribute('href'))

    contents = ""
    for idx, review in enumerate(links_review):
        # if idx > 1:
        #     break
        response = requests.get(review)
        html = response.text
        soup = BeautifulSoup(html, 'html.parser')
        # print(soup)
        res_src = requests.get('https://blog.naver.com' + soup.find('iframe')['src'])
        print('https://blog.naver.com' + soup.find('iframe')['src'])
        html_src = res_src.text
        soup_src = BeautifulSoup(html_src, 'html.parser')
        # print(soup_src)

        span_elements = soup_src.find_all('span')
        for span in span_elements:
            contents += " " + span.get_text().replace('\n', '').replace('\t', '')
    
        contents_list.append(contents)
        contents = ""

# print(contents_list)
df = pd.DataFrame(contents_list)
df

    # if idx != 0:
    #     browser.back()

    # browser.get(url)
        # browser.get(review)
        # time.sleep(1)
        # browser.execute_script("window.scrollTo(0,document.body.scrollHeight*1/7)")

        # browser.find_element(By.TAG_NAME, 'body').click()#.find_elements(By.TAG_NAME, 'span')
        # p = browser.find_element(By.TAG_NAME, 'iframe')
        # print(p.get_attribute('id'))
        # p_elements = p.find_elements(By.TAG_NAME, 'div')
        # print(len(p_elements))
        # for p in p_elements:
        #     contents += p.text
        #     print(contents)
        # span_elements = browser.find_elements(By.TAG_NAME, 'span')
        # print(len(span_elements))
        # for span in span_elements:
        #     contents += span.text
        #     print(contents)
        # browser.back()
# Out:
# https://blog.naver.com/032mm/223043619683
# https://blog.naver.com/jully97/223022872735
# https://blog.naver.com/miaphk98/223036324527
# https://blog.naver.com/kindohlee/223024573765
# https://blog.naver.com/toto0918/223028041567
# https://blog.naver.com/shiaru/222471711497
# https://blog.naver.com/km9511/223050877482
# https://blog.naver.com/PostView.naver?blogId=032mm&logNo=223043619683&redirect=Dlog&widgetTypeCall=true&directAccess=false
# https://blog.naver.com/PostView.naver?blogId
redirect=Dlog&widgetTypeCall=true&directAccess=false
# https://blog.naver.com/kindohlee/223033961480
# https://blog.naver.com/miaphk98/223051343356
# https://blog.naver.com/toto0918/222680530074
# https://blog.naver.com/kindohlee/223042448411
# https://blog.naver.com/kindohlee/223029180079
# https://blog.naver.com/toto0918/223026858833
# https://blog.naver.com/miaphk98/223043595734
# https://blog.naver.com/PostView.naver?blogId=kindohlee&logNo=223033961480&redirect=Dlog&widgetTypeCall=true&directAccess=false
# https://blog.naver.com/PostView.naver?blogId=miaphk98&logNo=223051343356&redirect=Dlog&widgetTypeCall=true&directAccess=false
# https://blog.naver.com/PostView.naver?blogId=toto0918&logNo=222680530074&redirect=Dlog&widgetTypeCall=true&directAccess=false
# https://blog.naver.com/PostView.naver?blogId=kindohlee&logNo=223042448411&redirect=Dlog&widgetTypeCall=true&directAccess=false
# https://blog.naver.com/PostView.naver?blogId=kindohlee&logNo=223029180079&redirect=Dlog&widgetTypeCall=true&directAccess=false
# https://blog.naver.com/PostView.naver?blogId=toto0918&logNo=223026858833&redirect=Dlog&widgetTypeCall=true&directAccess=false
# https://blog.naver.com/PostView.naver?blogId=miaphk98&logNo=223043595734&redirect=Dlog&widgetTypeCall=true&directAccess=false
# https://blog.naver.com/miaphk98/223043595734
# https://blog.naver.com/kindohlee/223026734382
# https://blog.naver.com/miaphk98/223047925570
# https://blog.naver.com/toto0918/223040854110
# https://blog.naver.com/kindohlee/223022180055
# https://blog.naver.com/kindohlee/223039368766
# https://blog.naver.com/toto0918/223022331949
# https://blog.naver.com/PostView.naver?blogId=miaphk98&logNo=223043595734&redirect=Dlog&widgetTypeCall=true&directAccess=false
# https://blog.naver.com/PostView.naver?blogId=kindohlee&logNo=223026734382&redirect=Dlog&widgetTypeCall=true&directAccess=false
# https://blog.naver.com/PostView.naver?blogId=miaphk98&logNo=223047925570&redirect=Dlog&widgetTypeCall=true&directAccess=false
# https://blog.naver.com/PostView.naver?blogId=toto0918&logNo=223040854110&redirect=Dlog&widgetTypeCall=true&directAccess=false
# https://blog.naver.com/PostView.naver?blogId=kindohlee&logNo=223022180055&redirect=Dlog&widgetTypeCall=true&directAccess=false
# https://blog.naver.com/PostView.naver?blogId=kindohlee&logNo=223039368766&redirect=Dlog&widgetTypeCall=true&directAccess=false
# https://blog.naver.com/PostView.naver?blogId=toto0918&logNo=223022331949&redirect=Dlog&widgetTypeCall=true&directAccess=false
# https://blog.naver.com/toto0918/223022331949
# https://blog.naver.com/miaphk98/223034661487
# https://blog.naver.com/miaphk98/223037904350
# https://blog.naver.com/toto0918/223042185967
# https://blog.naver.com/kindohlee/223025707659
# https://blog.naver.com/kindohlee/223041817072
# https://blog.naver.com/kindohlee/223037893664
# https://blog.naver.com/PostView.naver?blogId=toto0918&logNo=223022331949&redirect=Dlog&widgetTypeCall=true&directAccess=false
# https://blog.naver.com/PostView.naver?blogId=miaphk98&logNo=223034661487&redirect=Dlog&widgetTypeCall=true&directAccess=false
# https://blog.naver.com/PostView.naver?blogId=miaphk98&logNo=223037904350&redirect=Dlog&widgetTypeCall=true&directAccess=false
# https://blog.naver.com/PostView.naver?blogId=toto0918&logNo=223042185967&redirect=Dlog&widgetTypeCall=true&directAccess=false
# https://blog.naver.com/PostView.naver?blogId=kindohlee&logNo=223025707659&redirect=Dlog&widgetTypeCall=true&directAccess=false
# https://blog.naver.com/PostView.naver?blogId=kindohlee&logNo=223041817072&redirect=Dlog&widgetTypeCall=true&directAccess=false
# https://blog.naver.com/PostView.naver?blogId=kindohlee&logNo=223037893664&redirect=Dlog&widgetTypeCall=true&directAccess=false
#                                                     0
# 0      공감해요 댓글24 공유하기    로그인 맑은 정신 바른 자세 블로그 메뉴   ...
# 1      공감해요 댓글3 공유하기    로그인 평창동 호호줄리 블로그 메뉴       ...
# 2      공감해요 첫 댓글을 남겨보세요 공유하기    로그인 마요의 취미방 블로그 메뉴...
# 3     공유하기    로그인 EXHALE 블로그 메뉴       글쓰기 가벼운 글쓰기툴...
# 4      공감해요 첫 댓글을 남겨보세요 공유하기    로그인 스피릿님의 블로그 블로그 ...
# ..                                                ...
# 65     공감해요 첫 댓글을 남겨보세요 공유하기    로그인 마요의 취미방 블로그 메뉴...
# 66     공감해요 첫 댓글을 남겨보세요 공유하기    로그인 스피릿님의 블로그 블로그 ...
# 67    공유하기    로그인 EXHALE 블로그 메뉴       글쓰기 가벼운 글쓰기툴...
# 68     공감해요 첫 댓글을 남겨보세요 공유하기    로그인 EXHALE 블로그 메뉴 ...
# 69     공감해요 댓글3 공유하기    로그인 EXHALE 블로그 메뉴       글쓰...
#
# [70 rows x 1 columns]

# %%
from datetime import datetime

now = datetime.now()

print("문자열 변환 : ", now.strftime('%Y-%m-%d_%H:%M:%S'))
df.to_csv(f"{now.strftime('%Y-%m-%d_%H-%M-%S')}.csv", encoding="utf-8-sig")
# Out:
# 문자열 변환 :  2023-05-11_16:32:42

# %%
len(contents_list)
# Out:
# 70
